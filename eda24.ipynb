# %%
# Q1. What are the key features of the wine quality data set? Discuss the importance of each feature in
# predicting the quality of wine.
# Ans 1
import pandas as pd 
import seaborn as sns 
df=pd.read_csv('winequality-red.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
# volatile acidity :   Volatile acidity is the gaseous acids present in wine.
# fixed acidity :   Primary fixed acids found in wine are tartaric, succinic, citric, and malic
# residual sugar :   Amount of sugar left after fermentation.
# citric acid :    It is weak organic acid, found in citrus fruits naturally.
# chlorides :   Amount of salt present in wine.
# free sulfur dioxide :   So2 is used for prevention of wine by oxidation and microbial spoilage.
# total sulfur dioxide 
# pH :   In wine pH is used for checking acidity
# density 
# sulphates :    Added sulfites preserve freshness and protect wine from oxidation, and bacteria.
# alcohol :   Percent of alcohol present in wine.

# %%
# Q2. How did you handle missing data in the wine quality data set during the feature engineering process?
# Discuss the advantages and disadvantages of different imputation techniques.
# Ans 2: In the wine data set here is no missing value so i can use any techicnique but when in wine data set somewhere is missing data set i 
# put the find mean and median and put them. 
# Mean/median imputation:
# Advantages:

# It is a simple and quick method to implement.
# It works well when the data is missing at random and the missing values are not a large proportion of the data.
# It preserves the mean and standard deviation of the data, which is important in some statistical analyses.
# Disadvantages:

# It may not be the best method if the data has outliers or is not normally distributed.
# It can underestimate the variability of the data if the missing values are not distributed randomly.
# It can lead to biased estimates if the data is missing not at random.

# %%
# Q3. What are the key factors that affect students' performance in exams? How would you go about
# analyzing these factors using statistical techniques?
import pandas as  pd 
df1=pd.read_csv('stud.csv')
# this is the data and the lunch is effect the data and which person is good lunch and his performacne is good .
# Some initial steps we can take include:

# Checking for missing values and deciding how to handle them
# Looking at summary statistics for each variable, including mean, standard deviation, and quartiles
# Creating visualizations, such as histograms or box plots, to examine the distribution of each variable
# Conducting correlation analysis to identify any significant relationships between variables
# Once we have a better understanding of the data, we can start to build statistical models to identify the key factors
# that affect exam performance. For example, we can use linear regression to model the relationship between exam scores and various
# predictor variables, such as prior GPA, study habits, and test anxiety. We can also use hypothesis testing to determine whether
# certain variables have a significant effect on exam scores.

# %%
# Q4. Describe the process of feature engineering in the context of the student performance data set. How
# did you select and transform the variables for your model?
# Ans 4Feature engineering involves selecting, transforming, and creating variables to improve the performance of a 
# machine learning model. In the context of a student performance dataset, some variables that may be useful for 
# predicting exam scores could include prior GPA, attendance rates, and number of hours spent studying.

# To select and transform variables, we can use techniques such as correlation analysis and feature scaling. Correlation 
# analysis helps us identify variables that are highly correlated with exam scores, while feature scaling ensures that all 
# variables are on a comparable scale and have equal importance in the model. We can also create new variables, such as a 
# composite score that combines prior GPA and attendance rates, to improve the predictive power of the model.

# %%
# Q5. Load the wine quality data set and perform exploratory data analysis (EDA) to identify the distribution
# of each feature. Which feature(s) exhibit non-normality, and what transformations could be applied to
# these features to improve normality?
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df = pd.read_csv('winequality-red-Copy1.csv')

# Explore distribution of each feature
# sns.set_style('whitegrid')
sns.histplot(data=df, x='fixed acidity', kde=True)
plt.show()

sns.histplot(data=df, x='volatile acidity', kde=True)
plt.show()

sns.histplot(data=df, x='citric acid', kde=True)
plt.show()

sns.histplot(data=df, x='residual sugar', kde=True)
plt.show()

sns.histplot(data=df, x='chlorides', kde=True)
plt.show()

sns.histplot(data=df, x='free sulfur dioxide', kde=True)
plt.show()

sns.histplot(data=df, x='total sulfur dioxide', kde=True)
plt.show()

sns.histplot(data=df, x='density', kde=True)
plt.show()

sns.histplot(data=df, x='pH', kde=True)
plt.show()

sns.histplot(data=df, x='sulphates', kde=True)
plt.show()

sns.histplot(data=df, x='alcohol', kde=True)
plt.show()

# %%
# Q6. Using the wine quality data set, perform principal component analysis (PCA) to reduce the number of
# features. What is the minimum number of principal components required to explain 90% of the variance in
# the data?
import pandas as pd
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv('winequality.csv')

# Separate features and labels
X = df.drop('quality', axis=1)
y = df['quality']

# Perform PCA
pca = PCA()
X_pca = pca.fit_transform(X)

# Plot explained variance ratio
plt.plot(pca.explained_variance_ratio_.cumsum())
plt.xlabel('Number of Principal Components')
plt.ylabel('Cumulative Explained Variance Ratio')
plt.show()

# Determine minimum number of principal components to explain 90% of variance
n_components = 0
for i, variance in enumerate(pca.explained_variance_ratio_.cumsum()):
    if variance >= 0.9:
        n_components = i+1
        break
print("Minimum number of principal components required to explain 90% of variance:", n_components)
